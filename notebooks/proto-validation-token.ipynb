# %%
from google.oauth2 import id_token
from google.auth.transport import requests
import sqlalchemy as db

# %%
token = "eyJhbGciOiJSUzI1NiIsImtpZCI6IjIwOWMwNTdkM2JkZDhjMDhmMmQ1NzM5Nzg4NjMyNjczZjdjNjI0MGYiLCJ0eXAiOiJKV1QifQ.....opekYQppXFiRVnmAw8UUzdsP1xU0LJKrIfeTII3j0j9GNM2LaiBNELxydiVpQPoXYMoPSkA6KC8IVjAmL-a5o6RsKh5MFDrIEomWDXkza2sEsqEaLiAofOmpgVz8iMp3IiKhscrhuuY912ORYfv8AyK2Up4Z2Q25UkPCnI0Ksn6QP5dRiUGbo1Bno_oQSuDOVYzYwvQD6DakkfLqPbnEog3kWHb16mePriKXScRwkCnXPZ_CYDPvv9P-itY63kvp9VXcN-qurmMFf0KpYdpVozLL41MNen4LjNKqbZKpfIUu0KbgEGjB4IRMcdtRGSO8p66EgDqkO_ge6TfJNyiQiA"
client_id = "732264051436-0jgjer21ntnoi5ovilmgtqpghaj286sv.apps.googleusercontent.com"

# %%
idinfo = id_token.verify_oauth2_token(token, requests.Request(), client_id)

# %%
def connect_unix_socket() -> db.engine.base.Engine:
    db_user = "root" # e.g. 'my-database-user'
    db_pass = "sql&kollaidu31"  # e.g. 'my-database-password'
    db_name = "kollai_data"  # e.g. 'my-database'
    unix_socket_path = "/cloudsql/ai-canvas:europe-west1:sql-server" # e.g. '/cloudsql/project:region:instance'

    pool = db.create_engine(
        db.engine.url.URL.create(
            drivername="mysql+pymysql",
            username=db_user,
            password=db_pass,
            database=db_name,
            query={"unix_socket": unix_socket_path},),)
            
    return pool

# %%
def get_or_create(session, model, **kwargs):
    instance = session.query(model).filter_by(**kwargs).first()
    if instance:
        return instance
    else:
        instance = model(**kwargs)
        session.add(instance)
        return instance

# %%
engine = connect_unix_socket()

# %%
con = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\filou\anaconda3\envs\dashcanvas\lib\site-packages\pymysql\connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File c:\Users\filou\anaconda3\envs\dashcanvas\lib\socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
#     846 finally:
#     847     # Break explicitly a reference cycle
#
# File c:\Users\filou\anaconda3\envs\dashcanvas\lib\socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# ...

# %%
con.

# %%
engine = connect_unix_socket()
metadata = db.MetaData()
users = db.Table('users', metadata, autoload=True, autoload_with=engine)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\filou\anaconda3\envs\dashcanvas\lib\site-packages\pymysql\connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File c:\Users\filou\anaconda3\envs\dashcanvas\lib\socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
#     846 finally:
#     847     # Break explicitly a reference cycle
#
# File c:\Users\filou\anaconda3\envs\dashcanvas\lib\socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# ...

# %%
get_or_create(engine, )

# %%
idinfo
# Out:
# {'iss': 'https://accounts.google.com',
#  'nbf': 1663711099,
#  'aud': '732264051436-0jgjer21ntnoi5ovilmgtqpghaj286sv.apps.googleusercontent.com',
#  'sub': '101453466175389613106',
#  'email': 'philippe.henri.saade@gmail.com',
#  'email_verified': True,
#  'azp': '732264051436-0jgjer21ntnoi5ovilmgtqpghaj286sv.apps.googleusercontent.com',
#  'name': 'Philippe Saade',
#  'picture': 'https://lh3.googleusercontent.com/a/ALm5wu2X09kT1I8_wy9bucsCyXwqPc69RV-9LSdYmnGQ=s96-c',
#  'given_name': 'Philippe',
#  'family_name': 'Saade',
#  'iat': 1663711399,
#  'exp': 1663714999,
#  'jti': 'a7320715a54262f564be795a65e53727673d9a82'}
