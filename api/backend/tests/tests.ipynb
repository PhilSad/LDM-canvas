# %%
import sys
sys.path.append('../operations')

# %%
import dotenv
dotenv.load_dotenv('dev.env')
# Out:
# True

# %%
import db_operations
from importlib import reload
reload(db_operations)
# Out:
# <module 'db_operations' from '/mnt/c/Users/filou/OneDrive/Documents/Projet/LDM-canvas/api/backend/tests/../operations/db_operations.py'>

# %%
db_operations.get_images_from_room('default')
# Out:
# [{'imageID': 1323,
#   'path': 'default/20221001233809579239-Karl Marx portrait, digital art, hd, 4k, trending on art station.jpeg',
#   'posX': 1082.0,
#   'posY': 453.0,
#   'width': 330.0,
#   'height': 315.0,
#   'timestamp': datetime.datetime(2022, 10, 1, 23, 38, 9),
#   'prompt': 'Karl Marx portrait, digital art, hd, 4k, trending on art station',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1324,
#   'path': 'default/20221002001836515957-10 yo emmanuel macron.jpeg',
#   'posX': 577.0,
#   'posY': 436.0,
#   'width': 311.0,
#   'height': 325.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 18, 36),
#   'prompt': '10 yo emmanuel macron',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1325,
#   'path': 'default/20221002001918867058-child emmanuel macron.jpeg',
#   'posX': 137.0,
#   'posY': 449.0,
#   'width': 274.0,
#   'height': 244.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 19, 18),
#   'prompt': 'child emmanuel macron',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1326,
#   'path': 'default/20221002002003413320-child nicolas sarkosy.jpeg',
#   'posX': 137.0,
#   'posY': 213.0,
#   'width': 333.0,
#   'height': 201.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 20, 3),
#   'prompt': 'child nicolas sarkosy',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1327,
#   'path': 'default/20221002002110091242-child segolen royal.jpeg',
#   'posX': 530.0,
#   'posY': 198.0,
#   'width': 259.0,
#   'height': 214.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 21, 10),
#   'prompt': 'child segolen royal',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1328,
#   'path': 'default/20221002002118141338-fff.jpeg',
#   'posX': 884.0,
#   'posY': 243.0,
#   'width': 109.0,
#   'height': 91.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 21, 18),
#   'prompt': 'fff',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1329,
#   'path': 'default/20221002002219085243-child karl marx.jpeg',
#   'posX': 1103.0,
#   'posY': 143.0,
#   'width': 163.0,
#   'height': 160.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 22, 19),
#   'prompt': 'child karl marx',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1330,
#   'path': 'default/20221002002444624156-child santa claus.jpeg',
#   'posX': 854.0,
#   'posY': 60.0,
#   'width': 157.0,
#   'height': 152.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 24, 44),
#   'prompt': 'child santa claus',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1331,
#   'path': 'default/20221002002634308174-child edgar allan poe.jpeg',
#   'posX': 574.0,
#   'posY': 14.0,
#   'width': 204.0,
#   'height': 165.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 26, 34),
#   'prompt': 'child edgar allan poe',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1332,
#   'path': 'default/20221002002811138793-child obama.jpeg',
#   'posX': 319.0,
#   'posY': 32.0,
#   'width': 201.0,
#   'height': 156.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 28, 11),
#   'prompt': 'child obama',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1333,
#   'path': 'default/20221002003040940719-child trump.jpeg',
#   'posX': 1304.0,
#   'posY': 193.0,
#   'width': 239.0,
#   'height': 181.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 30, 40),
#   'prompt': 'child trump',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1334,
#   'path': 'default/20221002003110896908-Child muscular jesus.jpeg',
#   'posX': 1590.0,
#   'posY': 234.0,
#   'width': 283.0,
#   'height': 303.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 31, 10),
#   'prompt': 'Child muscular jesus',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1335,
#   'path': 'default/20221002003131890650-Karl Marx portrait, digital art, hd, 4k, trending on art station.jpeg',
#   'posX': 1251.0,
#   'posY': -219.0,
#   'width': 276.0,
#   'height': 269.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 31, 31),
#   'prompt': 'Karl Marx portrait, digital art, hd, 4k, trending on art station',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1336,
#   'path': 'default/20221002003424069027-      addNewPlaceholder(data.posX, data.posY, data.width, data.height).jpeg',
#   'posX': 1667.0,
#   'posY': -72.0,
#   'width': 235.0,
#   'height': 240.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 34, 24),
#   'prompt': '      addNewPlaceholder(data.posX, data.posY, data.width, data.height)',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1337,
#   'path': 'default/20221002003851241634-old muscular jesus.jpeg',
#   'posX': 2016.0,
#   'posY': 195.0,
#   'width': 408.0,
#   'height': 392.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 38, 51),
#   'prompt': 'old muscular jesus',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1338,
#   'path': 'default/20221002003920533996- / cameraZoom + cameraY - posY.jpeg',
#   'posX': 2066.0,
#   'posY': -141.0,
#   'width': 280.0,
#   'height': 280.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 39, 20),
#   'prompt': ' / cameraZoom + cameraY - posY',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1339,
#   'path': 'default/20221002004014342873-cute rabbits.jpeg',
#   'posX': 2518.0,
#   'posY': -207.0,
#   'width': 241.0,
#   'height': 235.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 40, 14),
#   'prompt': 'cute rabbits',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1340,
#   'path': 'default/20221002004016487458-cute rabbits.jpeg',
#   'posX': 2627.0,
#   'posY': 162.0,
#   'width': 253.0,
#   'height': 308.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 40, 16),
#   'prompt': 'cute rabbits',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1341,
#   'path': 'default/20221002004045971216-cute rabbits.jpeg',
#   'posX': 1974.0,
#   'posY': 748.0,
#   'width': 253.0,
#   'height': 272.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 40, 45),
#   'prompt': 'cute rabbits',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1342,
#   'path': 'default/20221002004047710048-cute rabbits.jpeg',
#   'posX': 2409.0,
#   'posY': 742.0,
#   'width': 211.0,
#   'height': 223.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 40, 47),
#   'prompt': 'cute rabbits',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1343,
#   'path': 'default/20221002004116073408-cute rabbits.jpeg',
#   'posX': 1611.0,
#   'posY': 851.0,
#   'width': 223.0,
#   'height': 259.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 41, 16),
#   'prompt': 'cute rabbits',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1344,
#   'path': 'default/20221002004118793360-cute rabbits.jpeg',
#   'posX': 1285.0,
#   'posY': 851.0,
#   'width': 266.0,
#   'height': 253.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 41, 18),
#   'prompt': 'cute rabbits',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1345,
#   'path': 'default/20221002004140230594-cute rabbits.jpeg',
#   'posX': 874.0,
#   'posY': 875.0,
#   'width': 374.0,
#   'height': 259.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 41, 40),
#   'prompt': 'cute rabbits',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1346,
#   'path': 'default/20221002004146340353-noose.jpeg',
#   'posX': 572.0,
#   'posY': -168.0,
#   'width': 208.0,
#   'height': 221.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 0, 41, 46),
#   'prompt': 'noose',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1347,
#   'path': "default/20221002010119662181-Hangman's knot.jpeg",
#   'posX': 1252.0,
#   'posY': -493.0,
#   'width': 273.0,
#   'height': 317.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 1, 1, 19),
#   'prompt': "Hangman's knot",
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1348,
#   'path': 'default/20221002010430863256-Cute cat with a wig.jpeg',
#   'posX': 1806.0,
#   'posY': 569.0,
#   'width': 163.0,
#   'height': 206.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 1, 4, 30),
#   'prompt': 'Cute cat with a wig',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1349,
#   'path': 'default/20221002010431994556-Cute cat with a wig.jpeg',
#   'posX': 1519.0,
#   'posY': 566.0,
#   'width': 243.0,
#   'height': 248.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 1, 4, 32),
#   'prompt': 'Cute cat with a wig',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1350,
#   'path': 'default/20221002010450526041-Cute cat with a wig.jpeg',
#   'posX': 1901.0,
#   'posY': 346.0,
#   'width': 108.0,
#   'height': 162.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 1, 4, 50),
#   'prompt': 'Cute cat with a wig',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1351,
#   'path': 'default/20221002010453819980-Cute cat with a wig.jpeg',
#   'posX': 2035.0,
#   'posY': 603.0,
#   'width': 192.0,
#   'height': 134.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 1, 4, 53),
#   'prompt': 'Cute cat with a wig',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1352,
#   'path': 'default/20221002013812842151-child nicolas sarkosy.jpeg',
#   'posX': 137.0,
#   'posY': 215.0,
#   'width': 250.0,
#   'height': 198.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 1, 38, 12),
#   'prompt': 'child nicolas sarkosy',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1353,
#   'path': 'default/20221002023215451851-Donal Trump mugshot.jpeg',
#   'posX': 878.0,
#   'posY': -244.0,
#   'width': 230.0,
#   'height': 199.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 2, 32, 15),
#   'prompt': 'Donal Trump mugshot',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1354,
#   'path': 'default/20221002023251586627-donal trump mugshot.jpeg',
#   'posX': 874.0,
#   'posY': -243.0,
#   'width': 233.0,
#   'height': 194.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 2, 32, 51),
#   'prompt': 'donal trump mugshot',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1355,
#   'path': 'default/20221002023323555477-donal trump mugshot.jpeg',
#   'posX': 876.0,
#   'posY': -244.0,
#   'width': 231.0,
#   'height': 188.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 2, 33, 23),
#   'prompt': 'donal trump mugshot',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1356,
#   'path': 'default/20221002024257045018-emmanuel macron as a child.jpeg',
#   'posX': 137.0,
#   'posY': 449.0,
#   'width': 273.0,
#   'height': 242.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 2, 42, 57),
#   'prompt': 'emmanuel macron as a child',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1357,
#   'path': 'default/20221002024328687169-emmanuel macron as a child.jpeg',
#   'posX': 137.0,
#   'posY': 447.0,
#   'width': 275.0,
#   'height': 245.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 2, 43, 28),
#   'prompt': 'emmanuel macron as a child',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1358,
#   'path': 'default/20221002024426022012-emmanuel macron drinking beer with a Gillet Jaune.jpeg',
#   'posX': -81.0,
#   'posY': 305.0,
#   'width': 155.0,
#   'height': 161.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 2, 44, 26),
#   'prompt': 'emmanuel macron drinking beer with a Gillet Jaune',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1359,
#   'path': 'default/20221002024520591429-vaporwave.jpeg',
#   'posX': 1302.0,
#   'posY': 192.0,
#   'width': 239.0,
#   'height': 181.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 2, 45, 20),
#   'prompt': 'vaporwave',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1360,
#   'path': 'default/20221002024554426699-vaporwave kitten.jpeg',
#   'posX': 1804.0,
#   'posY': 567.0,
#   'width': 163.0,
#   'height': 204.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 2, 45, 54),
#   'prompt': 'vaporwave kitten',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1361,
#   'path': 'default/20221002024629256328-muscular jesus.jpeg',
#   'posX': 2627.0,
#   'posY': 161.0,
#   'width': 251.0,
#   'height': 309.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 2, 46, 29),
#   'prompt': 'muscular jesus',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1362,
#   'path': 'default/20221002033514956145-child jose bove.jpeg',
#   'posX': 133.0,
#   'posY': 61.0,
#   'width': 148.0,
#   'height': 118.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 3, 35, 14),
#   'prompt': 'child jose bove',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1363,
#   'path': 'default/20221002034026918027-Jessie and James from the Team Rocket.jpeg',
#   'posX': 2408.0,
#   'posY': 740.0,
#   'width': 209.0,
#   'height': 225.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 3, 40, 26),
#   'prompt': 'Jessie and James from the Team Rocket',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1364,
#   'path': 'default/20221002034834929942-a cute rabbit cartoon.jpeg',
#   'posX': 1632.0,
#   'posY': -317.0,
#   'width': 153.0,
#   'height': 147.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 3, 48, 34),
#   'prompt': 'a cute rabbit cartoon',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1365,
#   'path': 'default/20221002105514081339-A communist utopia.jpeg',
#   'posX': 286.0,
#   'posY': 822.0,
#   'width': 360.0,
#   'height': 352.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 10, 55, 14),
#   'prompt': 'A communist utopia',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1366,
#   'path': 'default/20221002105548529351-.jpeg',
#   'posX': 77.0,
#   'posY': 824.0,
#   'width': 312.0,
#   'height': 349.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 10, 55, 48),
#   'prompt': '',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1367,
#   'path': 'default/20221002105554461512-.jpeg',
#   'posX': 589.0,
#   'posY': 823.0,
#   'width': 282.0,
#   'height': 349.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 10, 55, 54),
#   'prompt': '',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1368,
#   'path': 'default/20221002105623120634-A communist utopia.jpeg',
#   'posX': 77.0,
#   'posY': 826.0,
#   'width': 790.0,
#   'height': 344.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 10, 56, 23),
#   'prompt': 'A communist utopia',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1369,
#   'path': 'default/20221002121908492668-a cute rabbit.jpeg',
#   'posX': 3425.0,
#   'posY': -26.0,
#   'width': 285.0,
#   'height': 265.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 12, 19, 8),
#   'prompt': 'a cute rabbit',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1370,
#   'path': 'default/20221002122311565564-vaporwave rabbit.jpeg',
#   'posX': 4452.0,
#   'posY': -648.0,
#   'width': 269.0,
#   'height': 197.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 12, 23, 11),
#   'prompt': 'vaporwave rabbit',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1371,
#   'path': 'default/20221002122320776536-vaporwave rabbit.jpeg',
#   'posX': 4464.0,
#   'posY': -378.0,
#   'width': 256.0,
#   'height': 207.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 12, 23, 20),
#   'prompt': 'vaporwave rabbit',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1372,
#   'path': 'default/20221002123339650018-a cute angry rabbit.jpeg',
#   'posX': 2842.0,
#   'posY': -192.0,
#   'width': 186.0,
#   'height': 164.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 12, 33, 39),
#   'prompt': 'a cute angry rabbit',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1373,
#   'path': 'default/20221002123759624283-Donald Trump mugshot.jpeg',
#   'posX': 862.0,
#   'posY': -482.0,
#   'width': 208.0,
#   'height': 205.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 12, 37, 59),
#   'prompt': 'Donald Trump mugshot',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1374,
#   'path': 'default/20221002123912108028-Jesus fighting with a light saber.jpeg',
#   'posX': -281.0,
#   'posY': 508.0,
#   'width': 279.0,
#   'height': 258.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 12, 39, 12),
#   'prompt': 'Jesus fighting with a light saber',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1375,
#   'path': 'default/20221002123950121190-Dark Side Jesus, master of the gods.jpeg',
#   'posX': -362.0,
#   'posY': 295.0,
#   'width': 217.0,
#   'height': 186.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 12, 39, 50),
#   'prompt': 'Dark Side Jesus, master of the gods',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1376,
#   'path': 'default/20221002124020056090-Dark Side Jesus.jpeg',
#   'posX': -363.0,
#   'posY': 293.0,
#   'width': 218.0,
#   'height': 187.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 12, 40, 20),
#   'prompt': 'Dark Side Jesus',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1377,
#   'path': 'default/20221002124055716566-Dark Siduous Jesus.jpeg',
#   'posX': -363.0,
#   'posY': 293.0,
#   'width': 217.0,
#   'height': 188.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 12, 40, 55),
#   'prompt': 'Dark Siduous Jesus',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1378,
#   'path': 'default/20221002132320250588-Macron agreeing with Macron.jpeg',
#   'posX': -233.0,
#   'posY': 164.0,
#   'width': 109.0,
#   'height': 92.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 13, 23, 20),
#   'prompt': 'Macron agreeing with Macron',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1379,
#   'path': 'default/20221002132357375207-macron agreeing with macron.jpeg',
#   'posX': -270.0,
#   'posY': 126.0,
#   'width': 190.0,
#   'height': 157.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 13, 23, 57),
#   'prompt': 'macron agreeing with macron',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1380,
#   'path': 'default/20221002142012763793-harry potter during the covid year.jpeg',
#   'posX': 882.0,
#   'posY': 242.0,
#   'width': 110.0,
#   'height': 91.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 14, 20, 12),
#   'prompt': 'harry potter during the covid year',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1381,
#   'path': 'default/20221002145022906560-a cute bird.jpeg',
#   'posX': 1046.0,
#   'posY': -13.0,
#   'width': 157.0,
#   'height': 122.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 14, 50, 22),
#   'prompt': 'a cute bird',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1382,
#   'path': 'default/20221002172435195133-Francois Hollande as a child.jpeg',
#   'posX': 424.0,
#   'posY': 503.0,
#   'width': 141.0,
#   'height': 141.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 24, 35),
#   'prompt': 'Francois Hollande as a child',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1383,
#   'path': 'default/20221002172500643144-Francois Hollande as a child.jpeg',
#   'posX': 466.0,
#   'posY': 422.0,
#   'width': 65.0,
#   'height': 62.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 25),
#   'prompt': 'Francois Hollande as a child',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1384,
#   'path': 'default/20221002172506789764-Francois Hollande as a child.jpeg',
#   'posX': 435.0,
#   'posY': 653.0,
#   'width': 114.0,
#   'height': 116.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 25, 6),
#   'prompt': 'Francois Hollande as a child',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1385,
#   'path': 'default/20221002172519670352-Francois Hollande as a child.jpeg',
#   'posX': 307.0,
#   'posY': 710.0,
#   'width': 100.0,
#   'height': 101.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 25, 19),
#   'prompt': 'Francois Hollande as a child',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1386,
#   'path': 'default/20221002172611620165-Francois Hollande.jpeg',
#   'posX': -294.0,
#   'posY': 804.0,
#   'width': 260.0,
#   'height': 257.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 26, 11),
#   'prompt': 'Francois Hollande',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1387,
#   'path': 'default/20221002172646855024-Francois Hollande as a child.jpeg',
#   'posX': -293.0,
#   'posY': 806.0,
#   'width': 256.0,
#   'height': 252.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 26, 46),
#   'prompt': 'Francois Hollande as a child',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1388,
#   'path': 'default/20221002173406267963-Francois Hollande.jpeg',
#   'posX': -290.0,
#   'posY': 1086.0,
#   'width': 252.0,
#   'height': 268.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 34, 6),
#   'prompt': 'Francois Hollande',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1389,
#   'path': 'default/20221002173431531243-Francois Hollande portrait.jpeg',
#   'posX': -621.0,
#   'posY': 850.0,
#   'width': 271.0,
#   'height': 297.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 34, 31),
#   'prompt': 'Francois Hollande portrait',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1390,
#   'path': 'default/20221002173457903539-Francois Hollande as a child.jpeg',
#   'posX': -619.0,
#   'posY': 850.0,
#   'width': 265.0,
#   'height': 294.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 34, 57),
#   'prompt': 'Francois Hollande as a child',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1391,
#   'path': 'default/20221002173701879157-Francois Hollande.jpeg',
#   'posX': -622.0,
#   'posY': 574.0,
#   'width': 269.0,
#   'height': 264.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 37, 1),
#   'prompt': 'Francois Hollande',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1392,
#   'path': 'default/20221002173832819697-Francois Hollande as a child pouting in front of a plat of broccolis.jpeg',
#   'posX': -621.0,
#   'posY': 574.0,
#   'width': 266.0,
#   'height': 260.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 38, 32),
#   'prompt': 'Francois Hollande as a child pouting in front of a plat of broccolis',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1393,
#   'path': 'default/20221002173955187611-Donald Trump portrait.jpeg',
#   'posX': -348.0,
#   'posY': 1613.0,
#   'width': 139.0,
#   'height': 139.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 39, 55),
#   'prompt': 'Donald Trump portrait',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1394,
#   'path': 'default/20221002174021693899-Donald Trump as a child, portrait.jpeg',
#   'posX': -349.0,
#   'posY': 1613.0,
#   'width': 139.0,
#   'height': 138.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 40, 21),
#   'prompt': 'Donald Trump as a child, portrait',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1395,
#   'path': 'default/20221002174046401961-Donald Trump as a child, portrait.jpeg',
#   'posX': -349.0,
#   'posY': 1613.0,
#   'width': 138.0,
#   'height': 137.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 40, 46),
#   'prompt': 'Donald Trump as a child, portrait',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1396,
#   'path': 'default/20221002174404544725-Donald Trump, portrait, time magazine cover.jpeg',
#   'posX': -345.0,
#   'posY': 1471.0,
#   'width': 129.0,
#   'height': 126.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 17, 44, 4),
#   'prompt': 'Donald Trump, portrait, time magazine cover',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1397,
#   'path': 'default/20221002181305660459-Angela Merkel, portrait, photograph, high resolution.jpeg',
#   'posX': 8.0,
#   'posY': 564.0,
#   'width': 100.0,
#   'height': 100.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 18, 13, 5),
#   'prompt': 'Angela Merkel, portrait, photograph, high resolution',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1398,
#   'path': 'default/20221002181337978669-Angela Merkel as a child, portrait, photograph, high resolution.jpeg',
#   'posX': 8.0,
#   'posY': 564.0,
#   'width': 99.0,
#   'height': 98.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 18, 13, 37),
#   'prompt': 'Angela Merkel as a child, portrait, photograph, high resolution',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1399,
#   'path': 'default/20221002181421843796-Angela Merkel at age 8, portrait, photograph, high resolution.jpeg',
#   'posX': 9.0,
#   'posY': 564.0,
#   'width': 98.0,
#   'height': 98.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 18, 14, 21),
#   'prompt': 'Angela Merkel at age 8, portrait, photograph, high resolution',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1400,
#   'path': 'default/20221002181458449817-child Angela Merkel.jpeg',
#   'posX': 8.0,
#   'posY': 564.0,
#   'width': 98.0,
#   'height': 98.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 18, 14, 58),
#   'prompt': 'child Angela Merkel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1401,
#   'path': 'default/20221002185944417141-div .jpeg',
#   'posX': 918.0,
#   'posY': 601.0,
#   'width': 146.0,
#   'height': 147.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 18, 59, 44),
#   'prompt': 'div ',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1402,
#   'path': 'default/20221002190155474747-Jesus in Star Wars.jpeg',
#   'posX': -225.0,
#   'posY': -633.0,
#   'width': 348.0,
#   'height': 358.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 1, 55),
#   'prompt': 'Jesus in Star Wars',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1403,
#   'path': 'default/20221002190521556024-Ronald Mcdonald as a Star Wars sith.jpeg',
#   'posX': 143.0,
#   'posY': -627.0,
#   'width': 304.0,
#   'height': 340.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 5, 21),
#   'prompt': 'Ronald Mcdonald as a Star Wars sith',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1404,
#   'path': 'default/20221002190608717089-Kermit the frog as a Star Wars sith.jpeg',
#   'posX': -224.0,
#   'posY': -262.0,
#   'width': 337.0,
#   'height': 302.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 6, 8),
#   'prompt': 'Kermit the frog as a Star Wars sith',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1405,
#   'path': 'default/20221002190829368372-Ronald Mcdonald as a Star Wars sith.jpeg',
#   'posX': -547.0,
#   'posY': -632.0,
#   'width': 298.0,
#   'height': 354.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 8, 29),
#   'prompt': 'Ronald Mcdonald as a Star Wars sith',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1406,
#   'path': 'default/20221002190859391539-Cookie Monster as a Star Wars sith.jpeg',
#   'posX': -548.0,
#   'posY': -261.0,
#   'width': 299.0,
#   'height': 299.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 8, 59),
#   'prompt': 'Cookie Monster as a Star Wars sith',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1407,
#   'path': 'default/20221002192251981772-a cute rabbit.jpeg',
#   'posX': 857.0,
#   'posY': 370.0,
#   'width': 64.0,
#   'height': 66.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 22, 51),
#   'prompt': 'a cute rabbit',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1408,
#   'path': 'default/20221002192332589049-a cute rabbit.jpeg',
#   'posX': 803.0,
#   'posY': 299.0,
#   'width': 62.0,
#   'height': 56.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 23, 32),
#   'prompt': 'a cute rabbit',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1409,
#   'path': 'default/20221002192912140361-cute squirel.jpeg',
#   'posX': 1024.0,
#   'posY': 317.0,
#   'width': 50.0,
#   'height': 48.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 29, 12),
#   'prompt': 'cute squirel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1410,
#   'path': 'default/20221002192951637423-cute squirel.jpeg',
#   'posX': 1108.0,
#   'posY': 319.0,
#   'width': 81.0,
#   'height': 65.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 29, 51),
#   'prompt': 'cute squirel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1411,
#   'path': 'default/20221002193003231621-cute squirel.jpeg',
#   'posX': 1193.0,
#   'posY': 338.0,
#   'width': 59.0,
#   'height': 61.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 30, 3),
#   'prompt': 'cute squirel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1412,
#   'path': 'default/20221002193017820453-cute squirel.jpeg',
#   'posX': 1037.0,
#   'posY': 391.0,
#   'width': 52.0,
#   'height': 43.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 30, 17),
#   'prompt': 'cute squirel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1413,
#   'path': 'default/20221002193021277822-cute squirel.jpeg',
#   'posX': 1124.0,
#   'posY': 405.0,
#   'width': 50.0,
#   'height': 29.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 30, 21),
#   'prompt': 'cute squirel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1414,
#   'path': 'default/20221002193049102617-cute squirel.jpeg',
#   'posX': 1079.0,
#   'posY': 362.0,
#   'width': 21.0,
#   'height': 21.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 30, 49),
#   'prompt': 'cute squirel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1415,
#   'path': 'default/20221002193049938241-cute squirel.jpeg',
#   'posX': 983.0,
#   'posY': 371.0,
#   'width': 34.0,
#   'height': 29.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 30, 49),
#   'prompt': 'cute squirel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1416,
#   'path': 'default/20221002193114208021-cute squirel.jpeg',
#   'posX': 995.0,
#   'posY': 344.0,
#   'width': 26.0,
#   'height': 21.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 31, 14),
#   'prompt': 'cute squirel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1417,
#   'path': 'default/20221002193114354162-cute squirel.jpeg',
#   'posX': 1047.0,
#   'posY': 291.0,
#   'width': 32.0,
#   'height': 25.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 31, 14),
#   'prompt': 'cute squirel',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1418,
#   'path': 'default/20221002193129961578-Woooa ca spamme fort par ici.jpeg',
#   'posX': 948.0,
#   'posY': 419.0,
#   'width': 67.0,
#   'height': 62.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 31, 29),
#   'prompt': 'Woooa ca spamme fort par ici',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1419,
#   'path': 'default/20221002193237859279-A cute rabbit friend.jpeg',
#   'posX': 912.0,
#   'posY': 497.0,
#   'width': 62.0,
#   'height': 62.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 32, 37),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1420,
#   'path': 'default/20221002193237884998-A cute rabbit friend.jpeg',
#   'posX': 997.0,
#   'posY': 505.0,
#   'width': 53.0,
#   'height': 58.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 32, 37),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1421,
#   'path': 'default/20221002193306776766-A cute rabbit friend.jpeg',
#   'posX': 1035.0,
#   'posY': 450.0,
#   'width': 39.0,
#   'height': 33.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 33, 6),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1422,
#   'path': 'default/20221002193308950477-A cute rabbit friend.jpeg',
#   'posX': 926.0,
#   'posY': 350.0,
#   'width': 49.0,
#   'height': 51.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 33, 8),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1423,
#   'path': 'default/20221002193407100091-A cute rabbit friend.jpeg',
#   'posX': 792.0,
#   'posY': 367.0,
#   'width': 58.0,
#   'height': 54.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 34, 7),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1424,
#   'path': 'default/20221002193415307150-A cute rabbit friend.jpeg',
#   'posX': 793.0,
#   'posY': 219.0,
#   'width': 73.0,
#   'height': 69.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 34, 15),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1425,
#   'path': 'default/20221002193439844747-A cute rabbit friend.jpeg',
#   'posX': 1027.0,
#   'posY': 212.0,
#   'width': 63.0,
#   'height': 61.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 34, 39),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1426,
#   'path': 'default/20221002193443968126-A cute rabbit friend.jpeg',
#   'posX': 895.0,
#   'posY': 445.0,
#   'width': 46.0,
#   'height': 44.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 34, 43),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1427,
#   'path': 'default/20221002193543273901-A cute rabbit friend.jpeg',
#   'posX': 1001.0,
#   'posY': 278.0,
#   'width': 23.0,
#   'height': 25.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 35, 43),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1428,
#   'path': 'default/20221002193554835213-A cute rabbit friend.jpeg',
#   'posX': 1022.0,
#   'posY': 139.0,
#   'width': 59.0,
#   'height': 60.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 35, 54),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1429,
#   'path': 'default/20221002193605375552-A cute rabbit friend.jpeg',
#   'posX': 1032.0,
#   'posY': 137.0,
#   'width': 59.0,
#   'height': 60.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 36, 5),
#   'prompt': 'A cute rabbit friend',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1430,
#   'path': 'default/20221002193708927473-Kermit the ogre.jpeg',
#   'posX': 132.0,
#   'posY': -263.0,
#   'width': 258.0,
#   'height': 276.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 37, 8),
#   'prompt': 'Kermit the ogre',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1431,
#   'path': 'default/20221002194754628108-pouet.jpeg',
#   'posX': 534.0,
#   'posY': -577.0,
#   'width': 207.0,
#   'height': 244.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 47, 54),
#   'prompt': 'pouet',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1432,
#   'path': 'default/20221002194944986791-A duck.jpeg',
#   'posX': 449.0,
#   'posY': -277.0,
#   'width': 96.0,
#   'height': 107.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 49, 44),
#   'prompt': 'A duck',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1433,
#   'path': 'default/20221002195327556063-zoom.jpeg',
#   'posX': 925.0,
#   'posY': 760.0,
#   'width': 80.0,
#   'height': 82.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 53, 27),
#   'prompt': 'zoom',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1434,
#   'path': 'default/20221002195336937428-zoom.jpeg',
#   'posX': 1081.0,
#   'posY': 790.0,
#   'width': 61.0,
#   'height': 62.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 53, 36),
#   'prompt': 'zoom',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1435,
#   'path': 'default/20221002195544299621-Sonic the Hedgehog as a jedi.jpeg',
#   'posX': 905.0,
#   'posY': 1169.0,
#   'width': 205.0,
#   'height': 206.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 55, 44),
#   'prompt': 'Sonic the Hedgehog as a jedi',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1436,
#   'path': 'default/20221002195547662178-Sonic the Hedgehog as a sith.jpeg',
#   'posX': 1128.0,
#   'posY': 1170.0,
#   'width': 175.0,
#   'height': 197.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 55, 47),
#   'prompt': 'Sonic the Hedgehog as a sith',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1437,
#   'path': 'default/20221002195839140015-A better way.jpeg',
#   'posX': 634.0,
#   'posY': 1194.0,
#   'width': 141.0,
#   'height': 143.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 19, 58, 39),
#   'prompt': 'A better way',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1438,
#   'path': 'default/20221002200425199769-Test.jpeg',
#   'posX': 1878.0,
#   'posY': 2952.0,
#   'width': 120.0,
#   'height': 120.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 20, 4, 25),
#   'prompt': 'Test',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1439,
#   'path': 'default/20221002200534508890-Test.jpeg',
#   'posX': 1997.0,
#   'posY': 2952.0,
#   'width': 118.0,
#   'height': 119.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 20, 5, 34),
#   'prompt': 'Test',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1440,
#   'path': 'default/20221002201149306662-Daft Punk dogs.jpeg',
#   'posX': 1368.0,
#   'posY': 81.0,
#   'width': 102.0,
#   'height': 99.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 20, 11, 49),
#   'prompt': 'Daft Punk dogs',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1441,
#   'path': 'default/20221002201450799407-Karl Marx in the style of Regular Show.jpeg',
#   'posX': 1524.0,
#   'posY': 65.0,
#   'width': 100.0,
#   'height': 101.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 20, 14, 50),
#   'prompt': 'Karl Marx in the style of Regular Show',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1442,
#   'path': 'default/20221002201616338932-Karl Marx in Regular Show, season 5 episode 3.jpeg',
#   'posX': 1553.0,
#   'posY': -31.0,
#   'width': 79.0,
#   'height': 79.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 20, 16, 16),
#   'prompt': 'Karl Marx in Regular Show, season 5 episode 3',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1443,
#   'path': 'default/20221002201707875573-Karl Marx in Regular Show, season 5 episode 3.jpeg',
#   'posX': 1564.0,
#   'posY': -124.0,
#   'width': 79.0,
#   'height': 78.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 20, 17, 7),
#   'prompt': 'Karl Marx in Regular Show, season 5 episode 3',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1444,
#   'path': 'default/20221002221611698884-Jesus is king.jpeg',
#   'posX': -674.0,
#   'posY': 152.0,
#   'width': 303.0,
#   'height': 324.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 22, 16, 11),
#   'prompt': 'Jesus is king',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1445,
#   'path': 'default/20221002221710629545-Jesus with an angel halo.jpeg',
#   'posX': -674.0,
#   'posY': 106.0,
#   'width': 302.0,
#   'height': 317.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 22, 17, 10),
#   'prompt': 'Jesus with an angel halo',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1446,
#   'path': 'default/20221002222522520593-Techno furry.jpeg',
#   'posX': -887.0,
#   'posY': 325.0,
#   'width': 186.0,
#   'height': 197.0,
#   'timestamp': datetime.datetime(2022, 10, 2, 22, 25, 22),
#   'prompt': 'Techno furry',
#   'room': 'default',
#   'uuid': None,
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1456,
#   'path': 'default/20221003045036134506-donal trump pooping.jpeg',
#   'posX': 574.0,
#   'posY': 178.0,
#   'width': 18.0,
#   'height': 18.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 4, 50, 21),
#   'prompt': 'donal trump pooping',
#   'room': 'default',
#   'uuid': '522e638c-1d6e-4153-a674-d212f91d585c',
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1457,
#   'path': 'default/20221003045052761873-donal trump pooping.jpeg',
#   'posX': 593.0,
#   'posY': 178.0,
#   'width': 16.0,
#   'height': 14.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 4, 50, 25),
#   'prompt': 'donal trump pooping',
#   'room': 'default',
#   'uuid': '0e821112-d2de-45bc-ba13-3dbeba813d64',
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1458,
#   'path': 'default/20221003045104687016-donal trump pooping.jpeg',
#   'posX': 614.0,
#   'posY': 181.0,
#   'width': 19.0,
#   'height': 13.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 4, 50, 30),
#   'prompt': 'donal trump pooping',
#   'room': 'default',
#   'uuid': '503a217d-b6b6-4730-864d-c9965ca0a355',
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1459,
#   'path': 'default/20221003045120747965-donal trump pooping.jpeg',
#   'posX': 634.0,
#   'posY': 180.0,
#   'width': 17.0,
#   'height': 15.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 4, 50, 34),
#   'prompt': 'donal trump pooping',
#   'room': 'default',
#   'uuid': 'c8748835-06c2-4a4b-a0ff-be0f78991ed5',
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1460,
#   'path': 'default/20221003045136768270-.jpeg',
#   'posX': 653.0,
#   'posY': 180.0,
#   'width': 17.0,
#   'height': 15.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 4, 50, 39),
#   'prompt': '',
#   'room': 'default',
#   'uuid': '8910f12e-3e3d-4430-84f3-4d92d01f9555',
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1461,
#   'path': 'default/20221003045152995298-donal trump pooping.jpeg',
#   'posX': 672.0,
#   'posY': 180.0,
#   'width': 14.0,
#   'height': 15.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 4, 50, 47),
#   'prompt': 'donal trump pooping',
#   'room': 'default',
#   'uuid': '8bc5c0ec-3cc9-4f20-9e87-b535c47ad786',
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1462,
#   'path': 'default/20221003045617287451-vaporwave donald j trump.jpeg',
#   'posX': 3422.0,
#   'posY': -843.0,
#   'width': 332.0,
#   'height': 236.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 4, 54, 35),
#   'prompt': 'vaporwave donald j trump',
#   'room': 'default',
#   'uuid': '9f23e6e3-4b07-4b76-b10a-74c72f94d5c9',
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1463,
#   'path': 'default/20221003051635552128-child emmanuel macron.jpeg',
#   'posX': -254.0,
#   'posY': 154.0,
#   'width': 69.0,
#   'height': 103.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 5, 16, 31),
#   'prompt': 'child emmanuel macron',
#   'room': 'default',
#   'uuid': 'fbb60bb1-28b7-49bc-bb1c-59e0bb071ebe',
#   'status': 'generated',
#   'email': None},
#  {'imageID': 1464,
#   'path': 'default/20221003071410486673-spiderman.jpeg',
#   'posX': -173.0,
#   'posY': 50.0,
#   'width': 39.0,
#   'height': 33.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 7, 13, 57),
#   'prompt': 'spiderman',
#   'room': 'default',
#   'uuid': '42e1e388-5c0f-4acf-9ff7-8c2a6c6922e6',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1465,
#   'path': 'default/20221003073335890857-spiderman.jpeg',
#   'posX': 697.0,
#   'posY': 180.0,
#   'width': 22.0,
#   'height': 16.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 7, 33, 26),
#   'prompt': 'spiderman',
#   'room': 'default',
#   'uuid': 'eb6b32ac-8f17-4b38-9209-b71dbb20d363',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1466,
#   'path': 'default/20221003161847531637-spiderman.jpeg',
#   'posX': 601.0,
#   'posY': -317.0,
#   'width': 47.0,
#   'height': 49.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 16, 18, 32),
#   'prompt': 'spiderman',
#   'room': 'default',
#   'uuid': '6f23bc00-7bd8-4f96-88b3-f5c163e7694f',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1467,
#   'path': 'default/20221003161937545485-Emmanuel Macron as spiderman.jpeg',
#   'posX': 600.0,
#   'posY': -318.0,
#   'width': 47.0,
#   'height': 49.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 16, 19, 24),
#   'prompt': 'Emmanuel Macron as spiderman',
#   'room': 'default',
#   'uuid': 'ce6d73e2-a71a-49a8-b836-079a81d28782',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1468,
#   'path': 'default/20221003162022146680-Emmanuel Macron flying in the air.jpeg',
#   'posX': 599.0,
#   'posY': -319.0,
#   'width': 48.0,
#   'height': 50.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 16, 20, 10),
#   'prompt': 'Emmanuel Macron flying in the air',
#   'room': 'default',
#   'uuid': '11250520-6794-4239-a8e5-bdb158e74261',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1469,
#   'path': 'default/20221003162103134378-Emmanuel Macron flying in the air.jpeg',
#   'posX': 655.0,
#   'posY': -314.0,
#   'width': 40.0,
#   'height': 43.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 16, 20, 50),
#   'prompt': 'Emmanuel Macron flying in the air',
#   'room': 'default',
#   'uuid': '504f3946-d797-4ef6-887c-1e7ebea73255',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1470,
#   'path': 'default/20221003162353993645-grass background.jpeg',
#   'posX': 922.0,
#   'posY': 395.0,
#   'width': 98.0,
#   'height': 35.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 16, 23, 51),
#   'prompt': 'grass background',
#   'room': 'default',
#   'uuid': 'fac26ad7-d491-4784-b574-3f2638702272',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1471,
#   'path': 'default/20221003162430199003-grass background.jpeg',
#   'posX': 1160.0,
#   'posY': 422.0,
#   'width': 46.0,
#   'height': 35.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 16, 24, 22),
#   'prompt': 'grass background',
#   'room': 'default',
#   'uuid': '6260fc50-519b-46ab-8ed1-531bb1cd30be',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1472,
#   'path': 'default/20221003164653539842-Segolene Royale Times cover.jpeg',
#   'posX': -234.0,
#   'posY': 1469.0,
#   'width': 128.0,
#   'height': 129.0,
#   'timestamp': datetime.datetime(2022, 10, 3, 16, 46, 38),
#   'prompt': 'Segolene Royale Times cover',
#   'room': 'default',
# ...
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1605,
#   'path': 'default/20221007105958495022-Rabbit and squirrel in the grass.jpeg',
#   'posX': -6269.0,
#   'posY': 12239.0,
#   'width': 4136.0,
#   'height': 3536.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 10, 59, 44),
#   'prompt': 'Rabbit and squirrel in the grass',
#   'room': 'default',
#   'uuid': 'e3b60279-4adc-464e-a2a0-a7958caed728',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1606,
#   'path': 'default/20221007110109860243-A team skydivers clinging to a burning plane flying in the sky, digital art, 4k, trending on artstation.jpeg',
#   'posX': 627.0,
#   'posY': 14584.0,
#   'width': 4990.0,
#   'height': 5007.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 0, 56),
#   'prompt': 'A team skydivers clinging to a burning plane flying in the sky, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': '4d2dc45b-b657-462c-ad26-4986bbfd4086',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1607,
#   'path': 'default/20221007110151168142-A team skydivers clinging to a burning plane flying in the sky, digital art, 4k, trending on artstation.jpeg',
#   'posX': 578.0,
#   'posY': 14529.0,
#   'width': 10958.0,
#   'height': 10591.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 1, 34),
#   'prompt': 'A team skydivers clinging to a burning plane flying in the sky, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': '6272d1c0-b4ab-4b3e-8227-d2fece9294d1',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1608,
#   'path': 'default/20221007110259047040-Hot air balloon, digital art, 4k, trending on artstation.jpeg',
#   'posX': 9206.0,
#   'posY': 14630.0,
#   'width': 9998.0,
#   'height': 10491.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 2, 42),
#   'prompt': 'Hot air balloon, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': '88b47b3e-1a81-4073-b6e4-13769f0e4ebf',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1609,
#   'path': 'default/20221007110317025603-Sonic hot air balloon, digital art, 4k, trending on artstation.jpeg',
#   'posX': -2273.0,
#   'posY': 21543.0,
#   'width': 11355.0,
#   'height': 11109.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 3, 3),
#   'prompt': 'Sonic hot air balloon, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': '2743bda6-8936-4768-898a-c5c081a6bf11',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1610,
#   'path': 'default/20221007110355869305-Hot air balloon, digital art, 4k, trending on artstation.jpeg',
#   'posX': -10477.0,
#   'posY': 21577.0,
#   'width': 11101.0,
#   'height': 11031.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 3, 39),
#   'prompt': 'Hot air balloon, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': '8166f822-1863-4233-be74-2a5e336e38b2',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1611,
#   'path': 'default/20221007110435321917-Hot air balloon, digital art, 4k, trending on artstation.jpeg',
#   'posX': -19489.0,
#   'posY': 21624.0,
#   'width': 13656.0,
#   'height': 10985.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 4, 22),
#   'prompt': 'Hot air balloon, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': 'ba2ea17e-71e0-4c2a-a4de-2fb8454cf624',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1612,
#   'path': 'default/20221007110549590685-Luxurious green plains, digital art, 4k, trending on artstation.jpeg',
#   'posX': -19479.0,
#   'posY': 30527.0,
#   'width': 13629.0,
#   'height': 12842.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 5, 31),
#   'prompt': 'Luxurious green plains, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': '6e4f691b-1913-43d1-8e24-5f18863ce77a',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1613,
#   'path': 'default/20221007110559913985-Luxurious green plains, digital art, 4k, trending on artstation.jpeg',
#   'posX': -2168.0,
#   'posY': 30752.0,
#   'width': 11184.0,
#   'height': 10397.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 5, 43),
#   'prompt': 'Luxurious green plains, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': 'b57144e9-8c68-4fb6-b3f2-1064d68dba78',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1614,
#   'path': 'default/20221007110634655554-Luxurious green plains, digital art, 4k, trending on artstation.jpeg',
#   'posX': -9202.0,
#   'posY': 31986.0,
#   'width': 11675.0,
#   'height': 11419.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 6, 21),
#   'prompt': 'Luxurious green plains, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': '24527a72-a5d5-4d4c-a7f3-405f5d17f70f',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1615,
#   'path': 'default/20221007110736189293-Windmill in luxurious green plains, digital art, 4k, trending on artstation.jpeg',
#   'posX': -2281.0,
#   'posY': 38553.0,
#   'width': 11283.0,
#   'height': 12674.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 7, 20),
#   'prompt': 'Windmill in luxurious green plains, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': '1ee9d7bb-6fae-4867-8189-bd67ab1624d2',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1616,
#   'path': 'default/20221007110820617311-Windmill in luxurious green plains, digital art, 4k, trending on artstation.jpeg',
#   'posX': -11589.0,
#   'posY': 41122.0,
#   'width': 10405.0,
#   'height': 10167.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 8, 5),
#   'prompt': 'Windmill in luxurious green plains, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': 'bfae5975-6764-4d65-a3df-04ce5c341c0a',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1617,
#   'path': 'default/20221007110856984578-Gigantic sand worm, digital art, 4k, trending on artstation.jpeg',
#   'posX': -19444.0,
#   'posY': 41190.0,
#   'width': 9691.0,
#   'height': 10099.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 11, 8, 42),
#   'prompt': 'Gigantic sand worm, digital art, 4k, trending on artstation',
#   'room': 'default',
#   'uuid': '867a79aa-cc3a-4a4a-9885-5186507ed12f',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1618,
#   'path': 'default/20221007122009989243-The TARDIS.jpeg',
#   'posX': -5472.0,
#   'posY': 38420.0,
#   'width': 2351.0,
#   'height': 2935.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 12, 20, 2),
#   'prompt': 'The TARDIS',
#   'room': 'default',
#   'uuid': '173639a2-28f1-46f3-a774-dc9122564c5d',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1619,
#   'path': 'default/20221007145747739025-A dalek from doctor who.jpeg',
#   'posX': -1195.0,
#   'posY': 39255.0,
#   'width': 1469.0,
#   'height': 1547.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 14, 57, 36),
#   'prompt': 'A dalek from doctor who',
#   'room': 'default',
#   'uuid': '6c7208e4-8e84-4f77-9a20-3d2e2339f68e',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1620,
#   'path': "default/20221007150132225861-Shrek's city, digital art, 4k, trending on artstation .jpeg",
#   'posX': 24875.0,
#   'posY': -46863.0,
#   'width': 1524.0,
#   'height': 1599.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 15, 1, 20),
#   'prompt': "Shrek's city, digital art, 4k, trending on artstation ",
#   'room': 'default',
#   'uuid': '0e8dedf5-bfb2-44cd-a81a-f65c221a0a63',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1621,
#   'path': "default/20221007150334244697-Shrek's city, digital art, 4k, trending on artstation .jpeg",
#   'posX': 26145.0,
#   'posY': -46844.0,
#   'width': 1443.0,
#   'height': 1601.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 15, 3, 19),
#   'prompt': "Shrek's city, digital art, 4k, trending on artstation ",
#   'room': 'default',
#   'uuid': '29194e76-21ee-4f97-9cd1-80abc5dac2fb',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1622,
#   'path': "default/20221007150456353762-Shrek's statue from Shrek's city, digital art, 4k, trending on artstation .jpeg",
#   'posX': 27103.0,
#   'posY': -46844.0,
#   'width': 1702.0,
#   'height': 1606.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 15, 4, 39),
#   'prompt': "Shrek's statue from Shrek's city, digital art, 4k, trending on artstation ",
#   'room': 'default',
#   'uuid': 'f6f3b3f1-c1ad-4ed9-9038-e82072e4882b',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1623,
#   'path': "default/20221007150910974969-Shrek's city, digital art, 4k, trending on artstation .jpeg",
#   'posX': 23866.0,
#   'posY': -46796.0,
#   'width': 1514.0,
#   'height': 1678.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 15, 8, 55),
#   'prompt': "Shrek's city, digital art, 4k, trending on artstation ",
#   'room': 'default',
#   'uuid': 'ccf20ccd-9289-45bf-a393-509c4564208d',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1624,
#   'path': 'default/20221007172154333929-A dream of a dream.jpeg',
#   'posX': -46400.0,
#   'posY': 29154.0,
#   'width': 8262.0,
#   'height': 8262.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 21, 40),
#   'prompt': 'A dream of a dream',
#   'room': 'default',
#   'uuid': '6dbdf57a-87e8-4888-a871-7889c91341cb',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1625,
#   'path': 'default/20221007172818254120-A pot of gold at the source of a rainbow, Caspar David Friedrich.jpeg',
#   'posX': -27332.0,
#   'posY': 9742.0,
#   'width': 1102.0,
#   'height': 1038.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 28, 4),
#   'prompt': 'A pot of gold at the source of a rainbow, Caspar David Friedrich',
#   'room': 'default',
#   'uuid': 'b559f871-f93c-4f30-988d-b1e67c8ccca3',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1626,
#   'path': 'default/20221007172957724759-water pouring into a painting.jpeg',
#   'posX': -27331.0,
#   'posY': 8992.0,
#   'width': 993.0,
#   'height': 1133.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 29, 43),
#   'prompt': 'water pouring into a painting',
#   'room': 'default',
#   'uuid': 'ae3cc016-8505-415b-b893-df99466e13aa',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1627,
#   'path': 'default/20221007173117249401-A crying soul by Caspar David Friedrich.jpeg',
#   'posX': -27331.0,
#   'posY': 7950.0,
#   'width': 983.0,
#   'height': 1486.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 31, 5),
#   'prompt': 'A crying soul by Caspar David Friedrich',
#   'room': 'default',
#   'uuid': 'abf642d2-e7d2-48c7-9a08-8cd4252c879d',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1628,
#   'path': 'default/20221007173529996307-Weeping willow in a sea of clouds, Caspar David Friedrich.jpeg',
#   'posX': -29404.0,
#   'posY': 5595.0,
#   'width': 3538.0,
#   'height': 3395.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 35, 11),
#   'prompt': 'Weeping willow in a sea of clouds, Caspar David Friedrich',
#   'room': 'default',
#   'uuid': '144a28eb-86ce-4dfe-9426-90db7afc7568',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1629,
#   'path': 'default/20221007173704303657-A hazardous mountain in a sea of clouds, Caspar David Friedrich.jpeg',
#   'posX': -26658.0,
#   'posY': 5595.0,
#   'width': 3827.0,
#   'height': 3400.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 36, 49),
#   'prompt': 'A hazardous mountain in a sea of clouds, Caspar David Friedrich',
#   'room': 'default',
#   'uuid': 'e18b65b7-b3bf-4937-b45e-358c1212cd12',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1630,
#   'path': 'default/20221007173827478080-Squirrel in a rocky landscape, Caspar David Friedrich.jpeg',
#   'posX': -25907.0,
#   'posY': 7851.0,
#   'width': 3616.0,
#   'height': 3074.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 38, 13),
#   'prompt': 'Squirrel in a rocky landscape, Caspar David Friedrich',
#   'room': 'default',
#   'uuid': '5e4f99e5-6797-4bd8-a04b-52560a0636f4',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1631,
#   'path': 'default/20221007174038880176-Dragon flying in a sea of clouds.jpeg',
#   'posX': -29450.0,
#   'posY': 289.0,
#   'width': 6596.0,
#   'height': 7555.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 40, 24),
#   'prompt': 'Dragon flying in a sea of clouds',
#   'room': 'default',
#   'uuid': 'af56bf9f-546f-4060-9618-1749343b3975',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1632,
#   'path': 'default/20221007174548624499-Dragon in flight, Caspar David Friedrich.jpeg',
#   'posX': -26034.0,
#   'posY': 311.0,
#   'width': 9563.0,
#   'height': 8630.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 45, 34),
#   'prompt': 'Dragon in flight, Caspar David Friedrich',
#   'room': 'default',
#   'uuid': '251d7c3f-d688-429b-9588-75f6b926ed45',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1633,
#   'path': 'default/20221007174853867479-Castle in a sea of clouds, Caspar David Friedrich.jpeg',
#   'posX': 51823.0,
#   'posY': -2519.0,
#   'width': 1057.0,
#   'height': 1092.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 48, 41),
#   'prompt': 'Castle in a sea of clouds, Caspar David Friedrich',
#   'room': 'default',
#   'uuid': 'ca2259f8-ac6e-4b10-b269-7fc2975cf994',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1634,
#   'path': 'default/20221007175009296093-Dragon in flight, Caspar David Friedrich.jpeg',
#   'posX': 51814.0,
#   'posY': -2525.0,
#   'width': 2339.0,
#   'height': 2256.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 17, 49, 53),
#   'prompt': 'Dragon in flight, Caspar David Friedrich',
#   'room': 'default',
#   'uuid': '03dedf2d-9267-4933-becb-6f8546f9c96b',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1635,
#   'path': 'default/20221007183257319658-macron feeling cute.jpeg',
#   'posX': 483.0,
#   'posY': 216.0,
#   'width': 48.0,
#   'height': 48.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 18, 32, 43),
#   'prompt': 'macron feeling cute',
#   'room': 'default',
#   'uuid': '51243f0c-d1f2-4a63-b6cb-be3db82a089f',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1636,
#   'path': 'default/20221007184514165190-cute emmanuel macron.jpeg',
#   'posX': 18372.0,
#   'posY': -15415.0,
#   'width': 6188.0,
#   'height': 5202.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 18, 44, 48),
#   'prompt': 'cute emmanuel macron',
#   'room': 'default',
#   'uuid': 'b5cc482d-d504-4f4d-bd67-9971f6ccc8c3',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1637,
#   'path': 'default/20221007192428164653-cute lgbt emmanuel macron.jpeg',
#   'posX': -15021.0,
#   'posY': -18819.0,
#   'width': 2264.0,
#   'height': 1878.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 19, 24, 18),
#   'prompt': 'cute lgbt emmanuel macron',
#   'room': 'default',
#   'uuid': 'b8aadd9d-d846-4729-a5eb-37eaf4a19132',
#   'status': 'generated',
#   'email': 'philippe.henri.saade@gmail.com'},
#  {'imageID': 1638,
#   'path': 'default/20221007193010068074-Lizard overlord in a suit.jpeg',
#   'posX': -16365.0,
#   'posY': -18821.0,
#   'width': 1364.0,
#   'height': 1870.0,
#   'timestamp': datetime.datetime(2022, 10, 7, 19, 29, 55),
#   'prompt': 'Lizard overlord in a suit',
#   'room': 'default',
#   'uuid': '427244a2-6ff4-4b80-adb1-27cccc781cbf',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'},
#  {'imageID': 1837,
#   'path': 'default/20221009141108477565-Girl with a pearl earring, pixel art.webp',
#   'posX': 17617.0,
#   'posY': -6174.0,
#   'width': 13653.0,
#   'height': 18982.0,
#   'timestamp': datetime.datetime(2022, 10, 9, 14, 10, 58),
#   'prompt': 'Girl with a pearl earring, pixel art',
#   'room': 'default',
#   'uuid': 'e39e111d-d1c2-4291-be28-a6a036d7edcb',
#   'status': 'generated',
#   'email': 'ruben.g.gres@gmail.com'}]

# %%
import sqlalchemy
import sqlalchemy as db
import os

# %%
def connect_unix_socket() -> sqlalchemy.engine.base.Engine:
    db_user = os.environ["DB_USER"]  # e.g. 'my-database-user'
    db_pass = os.environ["DB_PASS"]  # e.g. 'my-database-password'
    db_name = os.environ["DB_NAME"]  # e.g. 'my-database'
    unix_socket_path = os.environ["INSTANCE_UNIX_SOCKET"]  # e.g. '/cloudsql/project:region:instance'

    pool = sqlalchemy.create_engine(
        sqlalchemy.engine.url.URL.create(
            drivername="mysql+pymysql",
            username=db_user,
            password=db_pass,
            database=db_name,
            host='127.0.0.1',
            port=3306
            # query={"unix_socket": unix_socket_path},
        )
    )
    return pool

engine = connect_unix_socket()

# %%
def get_table(name):
    return db.Table(name, db.MetaData(), autoload=True, autoload_with=engine)

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@127.0.0.1:3306/kollai_data)

# %%
get_table('images')
# Out:
# Table('images', MetaData(), Column('imageID', INTEGER(), table=<images>, primary_key=True, nullable=False), Column('path', VARCHAR(length=255), table=<images>), Column('posX', FLOAT(), table=<images>), Column('posY', FLOAT(), table=<images>), Column('width', FLOAT(), table=<images>), Column('height', FLOAT(), table=<images>), Column('timestamp', TIMESTAMP(), table=<images>, server_default=DefaultClause(<sqlalchemy.sql.elements.TextClause object at 0x7f90807775b0>, for_update=False)), Column('prompt', VARCHAR(length=1024), table=<images>), Column('room', VARCHAR(length=50), table=<images>), Column('uuid', VARCHAR(length=50), table=<images>), Column('status', VARCHAR(length=25), table=<images>), Column('email', VARCHAR(length=255), table=<images>), schema=None)
